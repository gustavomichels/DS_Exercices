# %%
import numpy as np

url = 'https://raw.githubusercontent.com/alura-cursos/numpy/dados/apples_ts.csv'

dados = np.loadtxt(url, delimiter=',', usecols = np.arange(1,88,1))

# %%
dados
# Out:
# array([[  1.2013,   2.2013,   3.2013,   4.2013,   5.2013,   6.2013,
#           7.2013,   8.2013,   9.2013,  10.2013,  11.2013,  12.2013,
#           1.2014,   2.2014,   3.2014,   4.2014,   5.2014,   6.2014,
#           7.2014,   8.2014,   9.2014,  10.2014,  11.2014,  12.2014,
#           1.2015,   2.2015,   3.2015,   4.2015,   5.2015,   6.2015,
#           7.2015,   8.2015,   9.2015,  10.2015,  11.2015,  12.2015,
#           1.2016,   2.2016,   3.2016,   4.2016,   5.2016,   6.2016,
#           7.2016,   8.2016,   9.2016,  10.2016,  11.2016,  12.2016,
#           1.2017,   2.2017,   3.2017,   4.2017,   5.2017,   6.2017,
#           7.2017,   8.2017,   9.2017,  10.2017,  11.2017,  12.2017,
#           1.2018,   2.2018,   3.2018,   4.2018,   5.2018,   6.2018,
#           7.2018,   8.2018,   9.2018,  10.2018,  11.2018,  12.2018,
#           1.2019,   2.2019,   3.2019,   4.2019,   5.2019,   6.2019,
#           7.2019,   8.2019,   9.2019,  10.2019,  11.2019,  12.2019,
# ...

# %%
dados.shape

# Mostra o tamanho de colunas e de linhas do dataset
# Out:
# (6, 87)

# %%
dados.ndim

# Mostra quantos dimensoes os dados estão variando, no caso 2 - linhas e colunas
# Out:
# 2

# %%
dados.size

# Mostra a quatnidade de informações do dataframe
# Out:
# 522

# %%
dado_transposto = dados.T

# Tranpoe os valores das colunas pelas linhas

# %%
dado_transposto.shape
# Out:
# (87, 6)

# %% [markdown]
# # Exercicio - 01

# %%
url = 'https://raw.githubusercontent.com/allanspadini/numpy/dados/citrus.csv'

exercicio = np.loadtxt(url,delimiter=',', usecols = np.arange(1,6,1), skiprows=1)
print(exercicio, exercicio.shape, exercicio.size)
# Out:
# [[  2.96  86.76 172.    85.     2.  ]
#  [  3.91  88.05 166.    78.     3.  ]
#  [  4.42  95.17 156.    81.     2.  ]
#  ...
#  [ 15.59 256.5  168.    82.    20.  ]
#  [ 15.92 260.14 142.    72.    11.  ]
#  [ 16.45 261.51 152.    74.     2.  ]] (10000, 5) 50000

# %% [markdown]
# --------------------------------FIM DOS EXERCICIOS-------------------------------------------------------

# %%
datas = dado_transposto[:,0]
datas

# : Indica que queremos selecionar todas as linhas ou colunas daquele dataset
# , Indica que queremos estamos selecionando todos as linhas de uma coluna especifica - 0
# Out:
# array([ 1.2013,  2.2013,  3.2013,  4.2013,  5.2013,  6.2013,  7.2013,
#         8.2013,  9.2013, 10.2013, 11.2013, 12.2013,  1.2014,  2.2014,
#         3.2014,  4.2014,  5.2014,  6.2014,  7.2014,  8.2014,  9.2014,
#        10.2014, 11.2014, 12.2014,  1.2015,  2.2015,  3.2015,  4.2015,
#         5.2015,  6.2015,  7.2015,  8.2015,  9.2015, 10.2015, 11.2015,
#        12.2015,  1.2016,  2.2016,  3.2016,  4.2016,  5.2016,  6.2016,
#         7.2016,  8.2016,  9.2016, 10.2016, 11.2016, 12.2016,  1.2017,
#         2.2017,  3.2017,  4.2017,  5.2017,  6.2017,  7.2017,  8.2017,
#         9.2017, 10.2017, 11.2017, 12.2017,  1.2018,  2.2018,  3.2018,
#         4.2018,  5.2018,  6.2018,  7.2018,  8.2018,  9.2018, 10.2018,
#        11.2018, 12.2018,  1.2019,  2.2019,  3.2019,  4.2019,  5.2019,
#         6.2019,  7.2019,  8.2019,  9.2019, 10.2019, 11.2019, 12.2019,
#         1.202 ,  2.202 ,  3.202 ])

# %%
precos = dado_transposto[:,1:6]
precos
# Out:
# array([[ 79.72,  42.67,  62.55,  48.26,  71.25],
#        [ 81.08,  44.37,  62.73,  51.01,  71.35],
#        [ 79.68,  44.73,  63.43,  50.91,  70.9 ],
#        [ 79.8 ,  46.75,  63.83,  53.94,  71.92],
#        [ 80.63,    nan,  66.06,  61.27,  72.91],
#        [ 80.8 ,  51.59,  69.22,  65.44,  74.39],
#        [ 80.28,  57.8 ,  72.07,  56.51,  73.1 ],
#        [ 78.99,  62.14,  69.31,  53.  ,  70.24],
#        [ 76.77,  56.76,  65.18,  43.87,  69.12],
#        [ 76.09,  50.85,  62.13,  42.12,  68.98],
#        [ 76.36,  46.43,  64.17,  43.98,  68.58],
#        [ 77.16,  46.73,  65.5 ,  44.66,  69.5 ],
#        [ 77.5 ,  45.85,  66.85,  47.73,  70.14],
#        [ 79.03,  49.25,  68.38,  52.31,  70.58],
#        [ 80.28,  48.14,  68.77,  56.8 ,  70.78],
#        [ 80.05,  49.18,  69.32,  51.15,  72.78],
#        [ 78.11,  49.49,  69.77,  54.63,  72.84],
#        [ 76.9 ,  49.83,  70.17,  55.8 ,  74.74],
#        [ 77.68,  49.14,  70.76,  57.31,  76.43],
# ...

# %%
import matplotlib.pyplot as plt

# %%
datas = np.arange(1,88,1)

# %%
plt.plot(datas, precos[:,0])

# %%
Moscow = precos[:,0]
Kaliningrad = precos[:,1]
Petersburg = precos[:,2]
Krasnodar = precos[:,3]
Ekaterinburg = precos[:,4]

# %%
plt.plot(Moscow)

# %%
Moscow.shape
# Out:
# (87,)

# %%
Moscow_ano1 = Moscow[0:12]
plt.plot(Moscow_ano1)

# %%
Moscow_ano1 = Moscow[0:12]
Moscow_ano2 = Moscow[13:25]
Moscow_ano3 = Moscow[26:38]
Moscow_ano4 = Moscow[39:51]

# %%
plt.plot(np.arange(1,13,1), Moscow_ano1)
plt.plot(np.arange(1,13,1), Moscow_ano2)
plt.plot(np.arange(1,13,1), Moscow_ano3)
plt.plot(np.arange(1,13,1), Moscow_ano4)

plt.legend(['Ano - 01','Ano - 02','Ano - 03','Ano - 04'], loc=0)

# %%
np.array_equal(Moscow_ano1,Moscow_ano2)

# Verifica se os 2 arrays sao iguais
# Out:
# False

# %%
np.allclose(Moscow_ano1,Moscow_ano2, 10)

# Verifica se os 2 arrays sao numericamente proximos, neste caso eles sao numericamente proximos por 10
# Out:
# True

# %%
sum(np.isnan(Kaliningrad))

# Verifica a quantidade de valores nan no dataset
# Out:
# 1

# %%
Kaliningrad[4] = np.mean([Kaliningrad[3], Kaliningrad[5]])

# %%
Kaliningrad
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,  49.17,  51.59,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
print(np.mean(Moscow),np.mean(Kaliningrad))
# Out:
# 98.79781609195402 74.5506896551724

# %% [markdown]
# # Exercicio 02

# %% [markdown]
# Chegou a hora de você testar os conhecimentos desenvolvidos durante a aula. Continuando com o projeto das laranjas/toranjas agora você deve selecionar parte dos dados. As colunas que iremos avaliar são as de diâmetro e peso. Crie arrays específicos para guardar o diâmetro e peso da laranja e toranja. O diâmetro está na coluna zero e o peso na coluna 1. Os dados referentes a laranja vão até a linha 4999 e os referentes à toranja iniciam na linha 5000 do arquivo.
#
# Após fazer a seleção de dados, importe a biblioteca matplotlib e crie um gráfico para a laranja e para a toranja do peso pelo diâmetro.

# %%
url = 'https://raw.githubusercontent.com/allanspadini/numpy/dados/citrus.csv'

exercicio = np.loadtxt(url, delimiter=',', skiprows=1, usecols=(1, 2))

# Delimiter é oq esta dividindo o dataset, skiprows significa para pular a primeira linha do dataset, 
# usecols esta falando para usar somente as colunas 2 e 3

diametro_laranja = exercicio[:5000,0]

# [: 5000] seleciona todas linhas de 0 a 4999 do dataset. [,0] significa para selecionar somente a coluna 0

peso_laranja = exercicio[:5000,1]

diametro_toranja = exercicio[5000:,0]
peso_toranja = exercicio[5000:,1]

plt.plot(diametro_laranja, peso_laranja)
plt.plot(diametro_toranja, peso_toranja)

plt.legend(['Laranja','Toranja'])

# %% [markdown]
# ---------------------------------------FIM DOS EXERCICIOS------------------------------------------------

# %%
plt.plot(datas, Moscow)

# %%
x = datas

y = 2 * x+ 80

plt.plot(datas,Moscow)
plt.plot(x,y)

# Equação da reta, a onde a = coeficiente angular, b = coeficiente linear, x = variavel usada para prever y

# Observamos que no grafico abaixo a linhas esta distante dos valores, idealmente queremos que a linha cruze os valores

# %%
Moscow - y

# Verificasse a diferenca entre os dados e a reta, os valores negativos significam que a reta esta acima da linha de dados
# Out:
# array([  -2.28,   -2.92,   -6.32,   -8.2 ,   -9.37,  -11.2 ,  -13.72,
#         -17.01,  -21.23,  -23.91,  -25.64,  -26.84,  -28.5 ,  -28.97,
#         -29.72,  -31.95,  -35.89,  -39.1 ,  -40.32,  -43.95,  -46.47,
#         -50.61,  -47.64,  -38.84,  -24.57,  -27.18,  -32.85,  -37.37,
#         -38.04,  -42.71,  -43.36,  -39.74,  -43.37,  -49.36,  -52.83,
#         -53.91,  -50.93,  -45.74,  -47.16,  -47.72,  -50.9 ,  -53.94,
#         -52.3 ,  -55.12,  -67.92,  -76.46,  -82.67,  -86.01,  -86.56,
#         -86.49,  -88.4 ,  -90.22,  -87.09,  -66.24,  -60.4 ,  -64.1 ,
#         -79.45,  -94.12,  -98.91,  -96.65,  -95.42,  -96.  ,  -91.05,
#         -86.83,  -87.52,  -84.42,  -82.11,  -86.64, -113.74, -126.55,
#        -129.07, -127.85, -126.9 , -125.  , -126.69, -128.99, -126.63,
#        -119.09, -112.71, -116.06, -128.97, -141.81, -148.17, -146.93,
#        -146.56, -143.77, -143.72])

# %%
np.power((Moscow - y),2)

# power = elevar o elemento, 2 = o quanto foi elevado no caso elevado ao quadrado
# Out:
# array([5.19840000e+00, 8.52640000e+00, 3.99424000e+01, 6.72400000e+01,
#        8.77969000e+01, 1.25440000e+02, 1.88238400e+02, 2.89340100e+02,
#        4.50712900e+02, 5.71688100e+02, 6.57409600e+02, 7.20385600e+02,
#        8.12250000e+02, 8.39260900e+02, 8.83278400e+02, 1.02080250e+03,
#        1.28809210e+03, 1.52881000e+03, 1.62570240e+03, 1.93160250e+03,
#        2.15946090e+03, 2.56137210e+03, 2.26956960e+03, 1.50854560e+03,
#        6.03684900e+02, 7.38752400e+02, 1.07912250e+03, 1.39651690e+03,
#        1.44704160e+03, 1.82414410e+03, 1.88008960e+03, 1.57926760e+03,
#        1.88095690e+03, 2.43640960e+03, 2.79100890e+03, 2.90628810e+03,
#        2.59386490e+03, 2.09214760e+03, 2.22406560e+03, 2.27719840e+03,
#        2.59081000e+03, 2.90952360e+03, 2.73529000e+03, 3.03821440e+03,
#        4.61312640e+03, 5.84613160e+03, 6.83432890e+03, 7.39772010e+03,
#        7.49263360e+03, 7.48052010e+03, 7.81456000e+03, 8.13964840e+03,
# ...

# %%
np.sum(np.power((Moscow - y),2))

# idealmente tentamos resumi-los em um unico valor
# Out:
# 561349.9641

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))

# sqrt = raiz quadrada do valor, tentando chegar mais proximo aos valores dos dados
# Este calculo define a qualidade do nosso ajuste, quanto menor mais qualidade
# Out:
# 749.2329171225728

# %%
y = 0.52*x+80
plt.plot(datas,Moscow)
plt.plot(x,y)

# Buscando um ajuste melhor

# %%
np.sqrt(np.sum(np.power(Moscow-y,2)))
# Out:
# 110.48504740461489

# %%
np.linalg.norm(Moscow-y)

# funcao do np que resume todos os calculos acima.
# Out:
# 110.48504740461489

# %% [markdown]
# <img width='700px' src='Dados/Imagem/formula.png'>
#
# â = coeficiente angular;
# n = número de elementos;
# Y = Moscow;
# X = datas.

# %%
Y = Moscow
X = datas
n = np.size(Moscow)

# %%
(X**2).shape
# Out:
# (87,)

# %%
a = (n*np.sum(X*Y) - np.sum(X)*np.sum(Y)) / (n*np.sum(X**2) - np.sum(X)**2)

# %%
b = np.mean(Y) - a * np.mean(X)

# %%
y = a*X + b

# %%
np.linalg.norm(Moscow-y)
# Out:
# 101.79695399927512

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)

# %% [markdown]
# Foi feito uma regressão linear, buscando estimar os valores dos dados em tal momento.

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)
plt.plot(41.5, 41.5*a+b, '*r')

# %%
plt.plot(datas,Moscow)
plt.plot(x,y)
plt.plot(100, 100 * a+b, '*r')

# Estimasse que o valor das maças no mes sem ultrapasse 120

# %% [markdown]
# # Exercicio 03
# Continuando com o projeto das laranjas/toranjas agora você deve calcular o coeficiente ângular e o linear para a reta da laranja e para a reta da toranja. Use a fórmula de mínimos quadrados para encontrar cada um.

# %%
plt.plot(diametro_laranja, peso_laranja)
plt.plot(diametro_toranja, peso_toranja)

plt.legend(['Laranja','Toranja'])

# %%
X_exercicio = diametro_laranja
Y_exercicio = peso_laranja
n_exercicio = np.size(X_exercicio)


a_exercicio = (n*np.sum(X_exercicio*Y_exercicio) - np.sum(X_exercicio)*np.sum(Y_exercicio)) / (n*np.sum(X_exercicio**2) - np.sum(X_exercicio)**2)
b_exercicio = np.mean(Y_exercicio) - a * np.mean(X_exercicio)
y_exercicio = a_exercicio*X_exercicio + b_exercicio

# %%
plt.plot(diametro_laranja, peso_laranja)
plt.plot(X_exercicio, y_exercicio)

# %% [markdown]
# ---------------------------------------FIM DOS EXERCICIOS------------------------------------------------

# %%
np.random.randint(40,100,10)

# Gera valores inteiros aleatorios, 40 - começo, 100 - final, 10 - quantidade de numeros
# Out:
# array([47, 69, 82, 51, 42, 67, 71, 60, 60, 73])

# %%
coef_angulares = np.random.uniform(0.10,0.90,100)

# Gera valores em float.

# %%
norma = np.array([])
# cria uma array list do numpy diferente de norma=[] que criaria uma lista do python
for i in range(100):
    norma = np.append(norma, np.linalg.norm(Moscow-(coef_angulares[i]*X+b)))
    
# Np.array([]) cria uma lista
# Np.append(x,y) adiciona os valores y na lista x
# np.linalg.norm calcula a norma de um vetor

# %%
norma
# Out:
# array([112.69975321, 105.35212248, 172.58050374, 169.98993974,
#        242.08030738, 114.38702507, 163.60417479, 115.34390116,
#        163.73674749, 122.48282956, 140.77432226, 158.44315948,
#        182.25093398, 125.59419056, 151.72222728, 134.91251225,
#        102.03644439, 107.21906229, 102.9966969 , 151.69245258,
#        156.42578246, 213.84422899, 189.41275734, 227.02487691,
#        105.64946222, 183.63735483, 108.84382479, 133.16856162,
#        124.8233244 , 114.50957628, 228.78272916, 156.97324546,
#        160.42268902, 214.86828806, 102.22121138, 147.84818779,
#        130.28696782, 112.90150866, 110.12964739, 176.21828477,
#        140.04333169, 212.95206369, 122.52990303, 150.17260675,
#        220.98238484, 122.3432522 , 109.62593802, 240.47038879,
#        153.7139827 , 109.4036709 , 102.80532535, 115.80246253,
#        112.83865806, 125.91352649, 103.61008589, 110.16053054,
#        212.19566552, 139.13276551, 104.80734564, 108.05971555,
# ...

# %%
np.random.seed(16)

# random.seed gera a semente para que os numeros aleatorios sejam sempre os mesmos

np.random.uniform(low=0.10,high=0.90,size=100)
# Out:
# array([0.27863286, 0.51853067, 0.54056117, 0.13648156, 0.38858307,
#        0.27846475, 0.65098093, 0.23098514, 0.15625989, 0.85280869,
#        0.5509451 , 0.16239387, 0.67811241, 0.22676174, 0.30022505,
#        0.3347898 , 0.65728857, 0.47141127, 0.27204971, 0.45746101,
#        0.196703  , 0.83414961, 0.55315706, 0.47761545, 0.35165314,
#        0.13457258, 0.70195593, 0.53461524, 0.71375234, 0.73235901,
#        0.1577771 , 0.62777267, 0.14263947, 0.64801956, 0.45468077,
#        0.47439692, 0.62884747, 0.65197331, 0.31066359, 0.10918315,
#        0.71703556, 0.75291386, 0.21171328, 0.5624054 , 0.37253942,
#        0.28577239, 0.258915  , 0.31719262, 0.88148221, 0.27234318,
#        0.38512593, 0.11471996, 0.59343222, 0.28432431, 0.69388139,
#        0.56740017, 0.43608284, 0.66740227, 0.87763642, 0.74803129,
#        0.44452414, 0.86618288, 0.13820648, 0.68622544, 0.64053316,
#        0.52160413, 0.55358996, 0.6783562 , 0.64608268, 0.73625014,
# ...

# %%
norma = np.array([])
np.random.seed(84)
# cria uma array list do numpy diferente de norma=[] que criaria uma lista do python
for i in range(100):
    norma = np.append(norma, np.linalg.norm(Moscow-(coef_angulares[i]*X+b)))
norma
# Out:
# array([112.69975321, 105.35212248, 172.58050374, 169.98993974,
#        242.08030738, 114.38702507, 163.60417479, 115.34390116,
#        163.73674749, 122.48282956, 140.77432226, 158.44315948,
#        182.25093398, 125.59419056, 151.72222728, 134.91251225,
#        102.03644439, 107.21906229, 102.9966969 , 151.69245258,
#        156.42578246, 213.84422899, 189.41275734, 227.02487691,
#        105.64946222, 183.63735483, 108.84382479, 133.16856162,
#        124.8233244 , 114.50957628, 228.78272916, 156.97324546,
#        160.42268902, 214.86828806, 102.22121138, 147.84818779,
#        130.28696782, 112.90150866, 110.12964739, 176.21828477,
#        140.04333169, 212.95206369, 122.52990303, 150.17260675,
#        220.98238484, 122.3432522 , 109.62593802, 240.47038879,
#        153.7139827 , 109.4036709 , 102.80532535, 115.80246253,
#        112.83865806, 125.91352649, 103.61008589, 110.16053054,
#        212.19566552, 139.13276551, 104.80734564, 108.05971555,
# ...

# %%
coef_angulares
# Out:
# array([0.33286458, 0.49263059, 0.73011655, 0.72329979, 0.89999604,
#        0.32479897, 0.7062379 , 0.32042717, 0.16380806, 0.57934316,
#        0.6409719 , 0.17826422, 0.75511019, 0.27953185, 0.67328122,
#        0.62256325, 0.42041658, 0.50644304, 0.40203117, 0.197208  ,
#        0.18386084, 0.83317467, 0.77322787, 0.86462635, 0.37537744,
#        0.75864128, 0.3536707 , 0.61689006, 0.28233371, 0.54617274,
#        0.86878413, 0.18233695, 0.69758313, 0.83563718, 0.45489026,
#        0.66210386, 0.60727978, 0.53853075, 0.3462736 , 0.13080632,
#        0.63872588, 0.83102651, 0.29088202, 0.66883992, 0.85027092,
#        0.2915929 , 0.52129839, 0.8962383 , 0.19146858, 0.35038142,
#        0.40480579, 0.55202662, 0.3321814 , 0.27838086, 0.47604139,
#        0.52430178, 0.82920315, 0.63590963, 0.48797816, 0.5119206 ,
#        0.32692923, 0.15359158, 0.32653657, 0.34564083, 0.40185273,
#        0.85333608, 0.51221463, 0.61248382, 0.76962263, 0.6499562 ,
# ...

# %%
dados = np.column_stack([norma, coef_angulares])

# np.column_stack junta duas listas em um unico array
dados.shape
# Out:
# (100, 2)

# %%
np.savetxt('dados.csv',dados,delimiter=',')

# salva os arquivos como csv

# %% [markdown]
# # Exercicio 4
#
# Continuando com o projeto das laranjas/toranjas, agora você deve calcular o coeficiente angular utilizando a geração de números aleatórios. Assuma que já conhece b e que este é igual a 17.

# %%
b_exercicio = 17
coef_angular_exercicio = np.random.uniform(0,30,10)
coef_angular_exercicio

norma = np.array([])

for i in range(len(coef_angular_exercicio)):
    norma = np.append(norma, np.linalg.norm(Y_exercicio-(coef_angular_exercicio[i]*X_exercicio+b_exercicio)))
    
norma
# Out:
# array([1326.38671921, 8984.34457212, 7524.89065284, 4734.77609589,
#        6660.57572265, 3182.73674202, 4388.20906402,  260.3603299 ,
#        5802.2273431 , 9260.77416569])
