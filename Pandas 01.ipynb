# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url,sep=';')

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.shape
# Out:
# (32960, 9)

# %%
dados.columns
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dados.describe()
# Out:
#             Quartos         Vagas        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#          Condominio          IPTU
# count  2.886700e+04  2.272300e+04
# mean   2.388062e+03  2.364410e+03
# std    3.918496e+04  1.795641e+05
# min    1.000000e+00  1.000000e+00
# 25%    5.900000e+02  1.100000e+02
# 50%    9.900000e+02  2.500000e+02
# 75%    1.800000e+03  6.970000e+02
# ...

# %%
dados.Valor.mean()
# Out:
# 12952.659715265761

# %%
dados.groupby('Tipo').mean(numeric_only=True)
# Out:
#                                Quartos      Vagas     Suites          Area  \
# Tipo
# Apartamento                   2.481569   1.232388   0.875998    119.790498
# Box/Garagem                   0.060976   1.304878   0.000000     17.524390
# Casa                          3.133402   1.795243   1.258532    250.578077
# Casa Comercial                1.562264   2.203774   0.260377    372.241509
# Casa de Condomínio            4.007028   3.101406   2.864458    456.161647
# Casa de Vila                  1.927711   0.389558   0.228916     78.469880
# Chácara                       3.000000   0.000000   0.000000      0.000000
# Conjunto Comercial/Sala       0.040939   2.516801   0.010858    214.472487
# Flat                          1.415966   0.962185   0.754202     65.483193
# Galpão/Depósito/Armazém       0.043339   5.587480   0.000000   2514.810594
# Hotel                        25.500000   2.500000  12.000000    885.500000
# ...

# %%
dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor', ascending = False)
# Out:
#                                      Valor
# Tipo
# Prédio Inteiro               498637.239203
# Indústria                    120000.000000
# Galpão/Depósito/Armazém       53407.062600
# Terreno Padrão                32567.714286
# Hotel                         25000.000000
# Loteamento/Condomínio         22000.000000
# Conjunto Comercial/Sala       14715.045521
# Casa Comercial                14478.264151
# Loja/Salão                    13769.646770
# Sítio                         12499.000000
# Casa de Condomínio            11952.061245
# Loja Shopping/ Ct Comercial    8126.178862
# Casa                           6793.454922
# Chácara                        4900.000000
# Apartamento                    4744.614648
# Flat                           4546.189076
# Loft                           2557.882353
# Studio                         2400.000000
# Box/Garagem                    1899.756098
# Casa de Vila                   1574.369478
# Pousada/Chalé                  1480.000000
# ...

# %%
df_preco_tipo = dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor', ascending = True)
df_preco_tipo.plot(kind='barh', figsize=(14,10), color='r')
# Out:
# <AxesSubplot: ylabel='Tipo'>

# %%
dados.Tipo.value_counts(normalize=True).round(5) * 100
# Out:
# Apartamento                    59.260
# Conjunto Comercial/Sala        20.677
# Loja/Salão                      4.326
# Casa de Condomínio              3.022
# Casa                            2.934
# Quitinete                       2.536
# Galpão/Depósito/Armazém         1.890
# Flat                            1.444
# Prédio Inteiro                  0.913
# Casa Comercial                  0.804
# Casa de Vila                    0.755
# Loja Shopping/ Ct Comercial     0.749
# Box/Garagem                     0.249
# Terreno Padrão                  0.212
# Loft                            0.155
# Sítio                           0.030
# Loteamento/Condomínio           0.015
# Studio                          0.012
# Hotel                           0.006
# Chácara                         0.003
# Pousada/Chalé                   0.003
# Indústria                       0.003
# Name: Tipo, dtype: float64

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala', 
                      'Prédio Inteiro', 'Loja/Salão', 
                      'Galpão/Depósito/Armazém', 
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# %%
dados.query('@imoveis_comerciais in Tipo')

# @ esta ai para puxar a variavel imoveis_comerciais
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
df = dados.query('@imoveis_comerciais not in Tipo')

# %%
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df_preco_tipo = df.groupby("Tipo").mean()[["Valor"]].sort_values("Valor")

df_preco_tipo.plot(kind='barh', figsize=(14, 10), color ='purple');

# %%
df.Tipo.value_counts(normalize=True).round(5) * 100
# Out:
# Apartamento           84.514
# Casa de Condomínio     4.310
# Casa                   4.184
# Quitinete              3.617
# Flat                   2.060
# Casa de Vila           1.077
# Loft                   0.221
# Studio                 0.017
# Name: Tipo, dtype: float64

# %%
df = df.query('Tipo == "Apartamento"')
df.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
# # Exercicio 01
#
# O time de ML chegou com algumas demandas de última hora para resolvermos nesse momento da análise exploratória. Essas demandas são:
#
# 1) Calcular a média de quartos por apartamento;
#
# 2) Conferir quantos bairros únicos existem na nossa base de dados;
#
# 3) Analisar quais bairros possuem a média de valor de aluguel mais elevadas;
#
# 4) Criar um gráfico de barras verticais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.

# %%
df.Quartos.mean()
# Out:
# 2.481568707761622

# %%
df.Bairro.unique()
# Out:
# array(['Centro', 'Higienópolis', 'Vista Alegre', 'Cachambi', 'Grajaú',
#        'Lins de Vasconcelos', 'Copacabana', 'Freguesia (Jacarepaguá)',
#        'Barra da Tijuca', 'Tijuca', 'Olaria', 'Ipanema', 'Botafogo',
#        'Recreio dos Bandeirantes', 'Leblon', 'Jardim Oceânico', 'Humaitá',
#        'Península', 'Méier', 'Vargem Pequena', 'Maracanã', 'Jacarepaguá',
#        'Jardim Botânico', 'Vila Valqueire', 'Gávea', 'Cosme Velho',
#        'Bonsucesso', 'Todos os Santos', 'Laranjeiras', 'Itanhangá',
#        'Praça Seca', 'Lagoa', 'Catete', 'Jardim Carioca', 'Vila Isabel',
#        'Rocha Miranda', 'Taquara', 'Engenho Novo', 'Campo Grande',
#        'Flamengo', 'Engenho de Dentro', 'São Conrado', 'Cidade Nova',
#        'Pilares', 'Tomás Coelho', 'Água Santa', 'São Cristóvão',
#        'Ilha do Governador', 'Vila da Penha', 'Anil', 'Vaz Lobo',
#        'Madureira', 'São Francisco Xavier', 'Pechincha', 'Leme', 'Irajá',
# ...

# %%
x = df.groupby("Bairro")[["Valor"]].mean().sort_values("Valor", ascending=True).head()

# %%
x.plot(kind='barh', figsize=(14,6), color='r')
# Out:
# <AxesSubplot: ylabel='Bairro'>

# %%
df.isnull().sum()
# Out:
# Tipo             0
# Bairro           0
# Quartos          0
# Vagas            0
# Suites           0
# Area             0
# Valor            7
# Condominio     745
# IPTU          5472
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Tipo          0
# Bairro        0
# Quartos       0
# Vagas         0
# Suites        0
# Area          0
# Valor         0
# Condominio    0
# IPTU          0
# dtype: int64

# %% [markdown]
# ------------------------------------------------------------------------------------------

# %%
df.Quartos == 1
# Out:
# 3         True
# 6        False
# 11       False
# 12       False
# 13        True
#          ...
# 32949    False
# 32950     True
# 32953    False
# 32956    False
# 32957    False
# Name: Quartos, Length: 13950, dtype: bool

# %%
selecao= df.Quartos == 1

# %%
selecao2 = df.Valor <= 1200

# %%
selecao_final = (selecao) & (selecao2)

# %%
df_1 = df[selecao_final]
df_1
# Out:
#               Tipo       Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3      Apartamento       Centro        1      0       0    15   800.0
# 28     Apartamento       Tijuca        1      0       0    48   750.0
# 54     Apartamento       Centro        1      0       0    27   750.0
# 94     Apartamento       Centro        1      1       0    37  1100.0
# 148    Apartamento  Vila Isabel        1      0       0    37  1000.0
# ...            ...          ...      ...    ...     ...   ...     ...
# 32580  Apartamento       Grajaú        1      1       0    56  1100.0
# 32617  Apartamento    Pechincha        1      0       1    69   900.0
# 32627  Apartamento       Glória        1      0       0    46  1100.0
# 32714  Apartamento     Botafogo        1      0       0    21  1000.0
# 32950  Apartamento       Tijuca        1      0       0    28  1000.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 28          772.0   25.0
# 54          371.0   19.0
# ...

# %%
df_2 = (df.Quartos == 2) & (df.Valor < 3000) & (df.Area > 70)
df[df_2]
# Out:
#               Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 21     Apartamento                    Tijuca        2      1       0   110
# 57     Apartamento  Recreio dos Bandeirantes        2      1       2    83
# 67     Apartamento                  Maracanã        2      0       0    86
# 68     Apartamento  Recreio dos Bandeirantes        2      1       1    74
# 93     Apartamento           Barra da Tijuca        2      1       1    88
# ...            ...                       ...      ...    ...     ...   ...
# 32876  Apartamento           Barra da Tijuca        2      1       1    72
# 32890  Apartamento   Freguesia (Jacarepaguá)        2      1       1    87
# 32933  Apartamento  Recreio dos Bandeirantes        2      1       1   105
# 32934  Apartamento               Jacarepaguá        2      1       1    78
# 32940  Apartamento           Barra da Tijuca        2      1       1    85
#
#         Valor  Condominio    IPTU
# ...

# %%
df.to_csv('dados_apartamento.csv', index=False)

# %%
pd.read_csv('dados_apartamento.csv')
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0      Apartamento                Centro        1      0       0    15
# 1      Apartamento              Cachambi        2      0       0    50
# 2      Apartamento                Grajaú        2      1       0    70
# 3      Apartamento   Lins de Vasconcelos        3      1       1    90
# 4      Apartamento            Copacabana        1      0       1    40
# ...            ...                   ...      ...    ...     ...   ...
# 13945  Apartamento               Ipanema        3      1       2   150
# 13946  Apartamento                Tijuca        1      0       0    28
# 13947  Apartamento                 Méier        2      0       0    70
# 13948  Apartamento           Jacarepaguá        3      1       2    78
# 13949  Apartamento  São Francisco Xavier        2      1       0    48
#
#          Valor  Condominio   IPTU
# 0        800.0       390.0   20.0
# 1       1300.0       301.0   17.0
# ...

# %% [markdown]
# # Exercicio 02

# %%
url2 = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
df_ex2 = pd.read_csv(url2)
df_ex2
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# 1) Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação

# %%
df_ex2 = df_ex2.fillna(0)
df_ex2
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# 2) Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.

# %%
df_ex2.query('Nome == "Alice" | Nome == "Carlos"')
# Out:
#      Nome  Idade  Notas  Aprovado
# 7  Carlos     19    6.0      True
# 8   Alice     35    5.6     False

# %%
df_ex2 = df_ex2.drop(df_ex2.query('Nome == "Alice" | Nome == "Carlos"').index)
df_ex2
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# 3) Aplique um filtro que selecione apenas os alunos que foram aprovados.

# %%
df_ex2_aprovados = df_ex2.query('Aprovado == True')
df_ex2_aprovados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %% [markdown]
# 4) Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".

# %%
df_ex2_aprovados.to_csv('alunos_aprovados.csv')

# %%
df_ex2_aprovados.replace(7.0, 8.0)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    8.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    8.0      True
# 17      Nadia     34    8.0      True

# %% [markdown]
# ------------------------------------------------------------------------------------------

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url,sep=';')

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados['Valor_por_mes'] = dados.Valor + dados.Condominio

# %%
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
# ...

# %%
dados['Valor_por_ano'] = (dados.Valor_por_mes * 12) + dados.IPTU

# %%
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
# ...

# %%
dados['Descrição'] = dados.Tipo +' Em '+ dados.Bairro + ' Possui ' + dados.Quartos.astype(str) + ' Quartos'
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
# ...

# %%
dados.fillna(0)
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
# ...

# %%
dados['Possui_Suite'] = dados.Suites.apply(lambda x: "Sim" if x > 0 else "Não")
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
# ...

# %% [markdown]
# # Exercicio 03

# %% [markdown]
# 1) Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles.

# %%
df_ex3 = pd.read_csv(url2)
df_ex3
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
df_ex3 = df_ex3.fillna(0)

# %%
df_ex3['Pontos_extras'] = df_ex3.Notas.apply(lambda x: x * 0.4)
df_ex3
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras
# 0         Ary     20    7.5      True           3.00
# 1         Ana     18    0.0     False           0.00
# 2       Cátia     27    2.5     False           1.00
# 3       Denis     18    5.0     False           2.00
# 4        Beto     21   10.0      True           4.00
# 5       Bruna     23    0.0     False           0.00
# 6        Dara     21    7.0      True           2.80
# 7      Carlos     19    6.0      True           2.40
# 8       Alice     35    5.6     False           2.24
# 9       Vitor     28    0.0     False           0.00
# 10     Daniel     21    0.0     False           0.00
# 11       Igor     24    4.5     False           1.80
# 12  Sthefanie     26    9.5      True           3.80
# 13      Mirla     25    9.0      True           3.60
# 14      Paulo     37    0.0     False           0.00
# 15     Mylena     29    7.0      True           2.80
# 16      Lucas     33    0.0     False           0.00
# ...

# %% [markdown]
# 2) Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras.

# %%
df_ex3['Notas_finais'] = df_ex3.Notas + df_ex3.Pontos_extras
df_ex3
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais
# 0         Ary     20    7.5      True           3.00         10.50
# 1         Ana     18    0.0     False           0.00          0.00
# 2       Cátia     27    2.5     False           1.00          3.50
# 3       Denis     18    5.0     False           2.00          7.00
# 4        Beto     21   10.0      True           4.00         14.00
# 5       Bruna     23    0.0     False           0.00          0.00
# 6        Dara     21    7.0      True           2.80          9.80
# 7      Carlos     19    6.0      True           2.40          8.40
# 8       Alice     35    5.6     False           2.24          7.84
# 9       Vitor     28    0.0     False           0.00          0.00
# 10     Daniel     21    0.0     False           0.00          0.00
# 11       Igor     24    4.5     False           1.80          6.30
# 12  Sthefanie     26    9.5      True           3.80         13.30
# ...

# %% [markdown]
# 3) Como houve uma pontuação extra, alguns alunos que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:
#
# True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
# False: caso o aluno esteja reprovado (nota final deve ser menor que 6).

# %%
df_ex3['Aprovado_final'] = df_ex3.Notas_finais.apply(lambda x:"Aprovado" if x >= 6 else "Reprovado")
df_ex3
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  \
# 0         Ary     20    7.5      True           3.00         10.50
# 1         Ana     18    0.0     False           0.00          0.00
# 2       Cátia     27    2.5     False           1.00          3.50
# 3       Denis     18    5.0     False           2.00          7.00
# 4        Beto     21   10.0      True           4.00         14.00
# 5       Bruna     23    0.0     False           0.00          0.00
# 6        Dara     21    7.0      True           2.80          9.80
# 7      Carlos     19    6.0      True           2.40          8.40
# 8       Alice     35    5.6     False           2.24          7.84
# 9       Vitor     28    0.0     False           0.00          0.00
# 10     Daniel     21    0.0     False           0.00          0.00
# 11       Igor     24    4.5     False           1.80          6.30
# 12  Sthefanie     26    9.5      True           3.80         13.30
# ...

# %% [markdown]
# 4) Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras.

# %%
df_ex3.query("(Aprovado == False) & (Aprovado_final == 'Aprovado')")
# Out:
#      Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais Aprovado_final
# 3   Denis     18    5.0     False           2.00          7.00       Aprovado
# 8   Alice     35    5.6     False           2.24          7.84       Aprovado
# 11   Igor     24    4.5     False           1.80          6.30       Aprovado
