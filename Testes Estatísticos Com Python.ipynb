# %%
import pandas as pd

tmdb = pd.read_csv('Dados/tmdb_5000_movies.csv')
import warnings
warnings.filterwarnings('ignore')

# %%
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
import seaborn as sns

ax = sns.distplot(tmdb.vote_average)
ax.set(xlabel='Nota Média', ylabel='Densidade')
ax.set_title('Média de votos em filmes no tmdb')
# Out:
# Text(0.5, 1.0, 'Média de votos em filmes no tmdb')

# %%
ax = sns.distplot(tmdb.vote_average, norm_hist = False, kde=False)
ax.set(xlabel='Nota Média', ylabel='Frequencia')
ax.set_title('Média de votos em filmes no tmdb')
# Out:
# Text(0.5, 1.0, 'Média de votos em filmes no tmdb')

# %%
ax = sns.boxplot(tmdb.vote_average)
ax.set_xlabel('Nota média do filme')
ax.set_title('Distribuição de nota média')
# Out:
# Text(0.5, 1.0, 'Distribuição de nota média')

# %%
tmdb.query('vote_average == 0')
# Out:
#        budget                                             genres  \
# 1464        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3670        0                  [{"id": 10751, "name": "Family"}]
# 3852        0                      [{"id": 18, "name": "Drama"}]
# 3855  3500000                [{"id": 99, "name": "Documentary"}]
# ...       ...                                                ...
# 4769        0  [{"id": 28, "name": "Action"}, {"id": 37, "nam...
# 4771        0                     [{"id": 27, "name": "Horror"}]
# 4780        0  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 4785        0                      [{"id": 18, "name": "Drama"}]
# 4794        0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
#
#                            homepage      id  \
# 1464                            NaN  310706
# 3669  http://www.romeothemovie.com/  113406
# 3670                            NaN  447027
# ...

# %%
tmdb_mais_que_10 = tmdb.query('vote_count >= 10')
tmdb_mais_que_10.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.392000e+03    4392.000000  4392.000000  4.392000e+03  4391.000000
# mean   3.164545e+07   49204.119991    23.448815  8.990969e+07   108.430881
# std    4.162736e+07   80136.249777    32.592158  1.682870e+08    21.014719
# min    0.000000e+00       5.000000     0.011697  0.000000e+00     0.000000
# 25%    2.895962e+06    8403.500000     6.512166  1.365700e+04    95.000000
# 50%    1.700000e+07   13084.500000    14.827784  2.685837e+07   105.000000
# 75%    4.200000e+07   46831.250000    30.258282  1.022818e+08   118.500000
# max    3.800000e+08  417859.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4392.000000   4392.000000
# mean       6.226935    754.441712
# std        0.893215   1272.263761
# min        1.900000     10.000000
# 25%        5.700000     83.750000
# 50%        6.300000    288.500000
# 75%        6.800000    831.000000
# ...

# %%
ax = sns.distplot(tmdb_mais_que_10.vote_average, norm_hist = False, kde=False)
ax.set(xlabel='Nota Média', ylabel='Frequencia')
ax.set_title('Média de votos em filmes no tmdb com pelo menos 10 votos')
# Out:
# Text(0.5, 1.0, 'Média de votos em filmes no tmdb com pelo menos 10 votos')

# %%
ax = sns.distplot(tmdb_mais_que_10.vote_average)
ax.set(xlabel='Nota Média', ylabel='Frequencia')
ax.set_title('Média de votos em filmes no tmdb com pelo menos 10 votos')
# Out:
# Text(0.5, 1.0, 'Média de votos em filmes no tmdb com pelo menos 10 votos')

# %%
ax = sns.boxplot(tmdb_mais_que_10.vote_average)
ax.set_xlabel('Nota média do filme')
ax.set_title('Distribuição de nota média')
# Out:
# Text(0.5, 1.0, 'Distribuição de nota média')

# %% [markdown]
# # Analisar o movielens

# %%
notas = pd.read_csv('Dados/ratings.csv')
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
nota_media_por_filme = notas.groupby('movieId').mean()['rating']
nota_media_por_filme
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: rating, Length: 9724, dtype: float64

# %%
ax = sns.distplot(nota_media_por_filme.values)
ax.set(xlabel='Nota Média', ylabel='Densidade')
ax.set_title('Média de votos em filmes no movielens')
# Out:
# Text(0.5, 1.0, 'Média de votos em filmes no movielens')

# %%
quantidade_votos_por_filme = notas.groupby('movieId').count()
filmes_com_pelo_menos_10_votos = quantidade_votos_por_filme.query('rating >= 10').index
filmes_com_pelo_menos_10_votos.values
# Out:
# array([     1,      2,      3, ..., 177765, 179819, 187593], dtype=int64)

# %%
nota_media_por_filme.loc[[1,3,5]]
# Out:
# movieId
# 1    3.920930
# 3    3.259615
# 5    3.071429
# Name: rating, dtype: float64

# %%
nota_media_filmes_10_votos = nota_media_por_filme.loc[filmes_com_pelo_menos_10_votos]
nota_media_filmes_10_votos
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 5         3.071429
# 6         3.946078
#             ...
# 174055    3.423077
# 176371    3.805556
# 177765    3.538462
# 179819    3.125000
# 187593    3.875000
# Name: rating, Length: 2269, dtype: float64

# %%
ax = sns.distplot(nota_media_filmes_10_votos.values)
ax.set(xlabel='Nota Média', ylabel='Densidade')
ax.set_title('Média de votos em filmes no movielens')
# Out:
# Text(0.5, 1.0, 'Média de votos em filmes no movielens')

# %%
ax = sns.boxplot(nota_media_filmes_10_votos.values)
ax.set_xlabel('Nota média do filme')
ax.set_title('Distribuição de nota média')
# Out:
# Text(0.5, 1.0, 'Distribuição de nota média')

# %%
ax = sns.distplot(nota_media_filmes_10_votos.values, 
                  hist_kws={'cumulative': True},
                  kde_kws={'cumulative':True})
ax.set(xlabel='Nota Média', ylabel='% acumulativa de filme')
ax.set_title('Média de votos em filmes no movielens')
# Out:
# Text(0.5, 1.0, 'Média de votos em filmes no movielens')

# %%
ax = sns.distplot(tmdb_mais_que_10.vote_average, 
                  hist_kws = {'cumulative':True}, 
                  kde_kws = {'cumulative':True})
ax.set(xlabel='Nota média', ylabel='Proporção acumulada de filmes')
ax.set_title('Média de votos em filmes no TMDB 5000')
# Out:
# Text(0.5, 1.0, 'Média de votos em filmes no TMDB 5000')

# %% [markdown]
# # Analisando a distribuição dos dados com outros campos do TMDB

# %%
ax = sns.distplot(tmdb_mais_que_10.vote_count)
ax.set(xlabel='Numero de votos', ylabel='Densidade')
ax.set_title('Numero de votos no tmbd com mais de 10 votos')
# Out:
# Text(0.5, 1.0, 'Numero de votos no tmbd com mais de 10 votos')

# %%
tmdb.query('budget > 0').budget
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4791           13
# 4792        20000
# 4796         7000
# 4798       220000
# 4799         9000
# Name: budget, Length: 3766, dtype: int64

# %%
ax = sns.distplot(tmdb.query('budget > 0').budget)
ax.set(xlabel='Gastos', ylabel='Densidade')
ax.set_title('Valor gasto em filmes no tmbd')
# Out:
# Text(0.5, 1.0, 'Valor gasto em filmes no tmbd')

# %%
ax = sns.distplot(tmdb.popularity)
ax.set(xlabel='Popularidade', ylabel='Densidade')
ax.set_title('Popularidade filmes no tmbd')
# Out:
# Text(0.5, 1.0, 'Popularidade filmes no tmbd')

# %%
tmdb.runtime.isnull().sum()
# Out:
# 2

# %%
tmdb.runtime.dropna()
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
#         ...
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
# Name: runtime, Length: 4801, dtype: float64

# %%
ax = sns.distplot(tmdb.query('runtime>0').runtime.dropna())
ax.set(xlabel='Duração', ylabel='Densidade')
ax.set_title('Duração filmes no tmbd')
# Out:
# Text(0.5, 1.0, 'Duração filmes no tmbd')

# %%
ax = sns.distplot(tmdb.query('runtime>0').runtime.dropna(),
                 hist_kws={'cumulative': True},
                 kde_kws={'cumulative': True})
ax.set(xlabel='Duração', ylabel='Densidade')
ax.set_title('Duração filmes no tmbd')
# Out:
# Text(0.5, 1.0, 'Duração filmes no tmbd')

# %%
tmdb.query('runtime>0').runtime.dropna().quantile(0.25)
# Out:
# 94.0

# %% [markdown]
# # Movielens: Média dos filmes com pelo menos 10 votos

# %%
nota_media_filmes_10_votos.mean()
# Out:
# 3.4320503405352603

# %%
nota_media_filmes_10_votos[0:1].mean()
# Out:
# 3.9209302325581397

# %%
import matplotlib.pyplot as plt

## Calcular com ordem aleatoria

import numpy as np
np.random.seed(75243)
temp = nota_media_filmes_10_votos.sample(frac=1)

medias = list()
for i in range(1, len(nota_media_filmes_10_votos)):
    medias.append(temp[0:i].mean())
    
## calculo da média pode ser feito com:
## medias = [temp[0:1].mean() for i in range(1,len(temp))]


plt.plot(medias)

# %%
from statsmodels.stats.weightstats import zconfint 

zconfint(nota_media_filmes_10_votos)
# Out:
# (3.4112459477469557, 3.452854733323563)

# %%
from statsmodels.stats.weightstats import DescrStatsW

descri_todos_10_votos = DescrStatsW(nota_media_filmes_10_votos)
descri_todos_10_votos.tconfint_mean()
# Out:
# (3.41123483922938, 3.4528658418411386)

# %% [markdown]
# # Analise filme 1

# %%
filmes = pd.read_csv('Dados/movies.csv')
filmes.query('movieId==1')
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
notas1 = notas.query('movieId==1')
notas1
# Out:
#        userId  movieId  rating   timestamp
# 0           1        1     4.0   964982703
# 516         5        1     4.0   847434962
# 874         7        1     4.5  1106635946
# 1434       15        1     2.5  1510577970
# 1667       17        1     4.5  1305696483
# ...       ...      ...     ...         ...
# 97364     606        1     2.5  1349082950
# 98479     607        1     4.0   964744033
# 98666     608        1     2.5  1117408267
# 99497     609        1     3.0   847221025
# 99534     610        1     5.0  1479542900
#
# [215 rows x 4 columns]

# %%
ax = sns.distplot(notas1.rating)
ax.set(xlabel='Nota média', ylabel='Densidade')
ax.set_title('Distribuição Nota toy story')
# Out:
# Text(0.5, 1.0, 'Distribuição Nota toy story')

# %%
ax = sns.boxplot(notas1.rating)
ax.set(xlabel='Nota média', ylabel='Densidade')
ax.set_title('Distribuição Nota toy story')
# Out:
# Text(0.5, 1.0, 'Distribuição Nota toy story')

# %%
notas1.rating.mean()
# Out:
# 3.9209302325581397

# %%
zconfint(notas1.rating)
# Out:
# (3.8093359183563402, 4.032524546759939)

# %%
from statsmodels.stats.weightstats import ztest

ztest(notas1.rating, value = 3.4320503405352603 )
# Out:
# (8.586342305916716, 8.978190401886942e-18)

# %%
np.random.seed(75241)
temp = notas1.sample(frac=1).rating

medias = [temp[0:i].mean() for i in range(1, len(temp))]
plt.plot(medias)

# %%
np.random.seed(75241)
temp = notas1.sample(frac=1).rating

def calcula_teste(i):
    media = temp[0:i].mean()
    stat, p = ztest(temp[0:i], value = 3.4320503405352603) 
    return (i, media, p)

valores = np.array([calcula_teste(i) for i in range(2, len(temp))])

plt.plot(valores[:,0], valores[:,1])

# %%
np.random.seed(75241)
temp = notas1.sample(frac=1).rating

def calcula_teste(i):
    media = temp[0:i].mean()
    stat, p = ztest(temp[0:i], value = 3.4320503405352603) 
    return (i, media, p)

valores = np.array([calcula_teste(i) for i in range(2, len(temp))])

plt.plot(valores[:,0], valores[:,1])
plt.plot(valores[:,0], valores[:,2], color='g')
plt.hlines(y=0.05, xmin=2, xmax=len(temp), colors='r')

# %% [markdown]
# # Comparação de dois conjuntos de amostras

# %%
print(ztest(notas1.rating, notas.rating))
zconfint(notas1.rating, notas.rating)
# Out:
# (5.894327101501841, 3.762112778881965e-09)
# (0.2799245129192442, 0.5588219849631111)

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(notas1.rating, notas.rating)
# Out:
# Ttest_indResult(statistic=5.894327101501841, pvalue=3.774003138720876e-09)

# %%
descr_todas_notas = DescrStatsW(notas.rating)
descr_toystory = DescrStatsW(notas1.rating)
comparacao = descr_todas_notas.get_compare(descr_toystory)
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
import matplotlib.pyplot as plt
plt.boxplot([notas.rating, notas1.rating], labels=['Todas as notas', 'Toy Story'])
plt.title('Dsitribuição de notas de acordo com filmes')
# Out:
# Text(0.5, 1.0, 'Dsitribuição de notas de acordo com filmes')

# %%
import matplotlib.pyplot as plt
plt.boxplot([notas.rating, notas1.rating[3:12]], labels=['Todas as notas', 'Toy Story 3-12'])
plt.title('Dsitribuição de notas de acordo com filmes')
# Out:
# Text(0.5, 1.0, 'Dsitribuição de notas de acordo com filmes')

# %%
descr_todas_notas = DescrStatsW(notas.rating)
descr_toystory = DescrStatsW(notas1[3:12].rating)
comparacao = descr_todas_notas.get_compare(descr_toystory)
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# # Comparar a media de dois filmes

# %%
filmes.query('movieId in [1,593,72226]')
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 510       593  Silence of the Lambs, The (1991)
# 7180    72226          Fantastic Mr. Fox (2009)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 510                         Crime|Horror|Thriller
# 7180    Adventure|Animation|Children|Comedy|Crime

# %%
notas593 = notas.query('movieId == 593')
notas72226 = notas.query('movieId == 72226')
plt.boxplot([notas1.rating, notas593.rating, notas72226.rating], labels = ['Toy Story','Silencio','Raposa'])
plt.title('Distribuição das notas de acordo com os filmes')
# Out:
# Text(0.5, 1.0, 'Distribuição das notas de acordo com os filmes')

# %%
notas72226.describe()
# Out:
#            userId  movieId     rating     timestamp
# count   18.000000     18.0  18.000000  1.800000e+01
# mean   329.722222  72226.0   4.083333  1.395218e+09
# std    174.748157      0.0   0.895249  9.459862e+07
# min     73.000000  72226.0   1.500000  1.262899e+09
# 25%    167.000000  72226.0   4.000000  1.279706e+09
# 50%    326.000000  72226.0   4.250000  1.441777e+09
# 75%    466.250000  72226.0   4.500000  1.471770e+09
# max    610.000000  72226.0   5.000000  1.498522e+09

# %%
sns.boxplot(x='movieId', y='rating', data= notas.query('movieId in (1,593,72226)'))
# Out:
# <AxesSubplot:xlabel='movieId', ylabel='rating'>

# %%
descr_1 = DescrStatsW(notas1.rating)
descr_593 = DescrStatsW(notas593.rating)
comparacao = descr_1.get_compare(descr_593)
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
descr_1 = DescrStatsW(notas1.rating)
descr_72226 = DescrStatsW(notas72226.rating)
comparacao = descr_1.get_compare(descr_72226)
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
descr_593 = DescrStatsW(notas593.rating)
descr_72226 = DescrStatsW(notas72226.rating)
comparacao = descr_593.get_compare(descr_72226)
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
data= notas.query('movieId in (1,593,72226)').groupby('movieId').count()
data
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 593         279     279        279
# 72226        18      18         18

# %%
from scipy.stats import normaltest

# %%
stats,p = normaltest(notas1.rating)
p
# Out:
# 0.00011053430732728716

# %%
from scipy.stats import ranksums
ranksums(notas1.rating, notas593.rating)
# Out:
# RanksumsResult(statistic=-3.5930962013771377, pvalue=0.0003267718756440693)
